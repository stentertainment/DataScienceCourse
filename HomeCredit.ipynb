# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/stentertainment/DataScienceCourse/blob/master/HomeCredit.ipynb)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-21340fac-dcf6-46cc-af99-68d4d7aa12f9" name="files[]" multiple disabled />
#      <output id="result-21340fac-dcf6-46cc-af99-68d4d7aa12f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train_bureau_raw.csv to train_bureau_raw.csv
# Saving test_bureau_raw.csv to test_bureau_raw.csv

# %%
import pandas as pd
import io

train = pd.read_csv(io.StringIO(uploaded['train_bureau_raw.csv'].decode('utf-8')))
test = pd.read_csv(io.StringIO(uploaded['test_bureau_raw.csv'].decode('utf-8')))

# %%
app_train = train
app_train.head(10)
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
# 5      100008       0         Cash loans           M            N
# 6      100009       0         Cash loans           F            Y
# 7      100010       0         Cash loans           M            Y
# 8      100011       0         Cash loans           F            N
# 9      100012       0    Revolving loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# ...

# %%
app_test = test
app_test.head(10)
# Out:
#    SK_ID_CURR NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0      100001         Cash loans           F            N               Y
# 1      100005         Cash loans           M            N               Y
# 2      100013         Cash loans           M            Y               Y
# 3      100028         Cash loans           F            N               Y
# 4      100038         Cash loans           M            Y               N
# 5      100042         Cash loans           F            Y               Y
# 6      100057         Cash loans           M            Y               Y
# 7      100065         Cash loans           M            N               Y
# 8      100066         Cash loans           F            N               Y
# 9      100067         Cash loans           F            Y               Y
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0             0          135000.0    568800.0      20560.5         450000.0
# ...

# %%
print('Training Data Shape: ', app_train.shape)
print('Testing Data Shape: ', app_test.shape)
# Out:
# Training Data Shape:  (307511, 334)
# Testing Data Shape:  (48744, 332)

# %%
# matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
import seaborn as sns

# Suppress warnings from pandas
import warnings
warnings.filterwarnings('ignore')

plt.style.use('fivethirtyeight')

# %%
# Calculate all correlations in dataframe
corrs = app_train.corr()

# %%
corrs = corrs.sort_values('TARGET', ascending = False)

# Ten most positive correlations
pd.DataFrame(corrs['TARGET'].head(10))
# Out:
#                                                   TARGET
# TARGET                                          1.000000
# bureau_DAYS_CREDIT_mean                         0.089729
# client_bureau_balance_MONTHS_BALANCE_min_mean   0.089038
# DAYS_BIRTH                                      0.078239
# bureau_CREDIT_ACTIVE_Active_count_norm          0.077356
# client_bureau_balance_MONTHS_BALANCE_mean_mean  0.076424
# bureau_DAYS_CREDIT_min                          0.075248
# client_bureau_balance_MONTHS_BALANCE_min_min    0.073225
# client_bureau_balance_MONTHS_BALANCE_sum_mean   0.072606
# bureau_DAYS_CREDIT_UPDATE_mean                  0.068927

# %%
# Drop SK_ID_CURR column from train and test
app_train = app_train.drop('SK_ID_CURR', axis=1)

# %%
app_test = app_test.drop('SK_ID_CURR', axis=1)

# %%
app_train.head(5)
# Out:
#    TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0       1         Cash loans           M            N               Y
# 1       0         Cash loans           F            N               N
# 2       0    Revolving loans           M            Y               Y
# 3       0         Cash loans           F            N               Y
# 4       0         Cash loans           M            N               Y
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0             0          202500.0    406597.5      24700.5         351000.0
# 1             0          270000.0   1293502.5      35698.5        1129500.0
# 2             0           67500.0    135000.0       6750.0         135000.0
# 3             0          135000.0    312682.5      29686.5         297000.0
# 4             0          121500.0    513000.0      21865.5         513000.0
#
#                        ...                        \
# 0                      ...
# ...

# %%
app_test.head(5)
# Out:
#   NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0         Cash loans           F            N               Y             0
# 1         Cash loans           M            N               Y             0
# 2         Cash loans           M            Y               Y             0
# 3         Cash loans           F            N               Y             2
# 4         Cash loans           M            Y               N             1
#
#    AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE NAME_TYPE_SUITE  \
# 0          135000.0    568800.0      20560.5         450000.0   Unaccompanied
# 1           99000.0    222768.0      17370.0         180000.0   Unaccompanied
# 2          202500.0    663264.0      69777.0         630000.0             NaN
# 3          315000.0   1575000.0      49018.5        1575000.0   Unaccompanied
# 4          180000.0    625500.0      32067.0         625500.0   Unaccompanied
#
# ...

# %%
# Create a function that
def mean_age_by_group(df, col):
    # groups the data by a column and returns the mean age per group
    return df.groupby(col).mean()

# %%
# Create a function that
def uppercase_column_name(dataframe):
    # Capitalizes all the column headers
    dataframe.columns = dataframe.columns.str.upper()
    # And returns them
    return dataframe

# %%
# Create a pipeline that applies the mean_age_by_group function
(app_train.pipe(mean_age_by_group, col='gender')
   # then applies the uppercase column name function
   .pipe(uppercase_column_name)
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-74092d3a8fcb> in <module>()
# ----> 1 (app_train.pipe(mean_age_by_group, col='gender')
#       2    # then applies the uppercase column name function
#       3    .pipe(uppercase_column_name)
#       4 )
#
# NameError: name 'app_train' is not defined
